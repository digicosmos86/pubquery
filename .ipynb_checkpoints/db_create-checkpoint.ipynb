# %% [markdown]
# ## Project Stage 1: Database Creation
#
# This jupyter notebook documents the Python code and SQL syntax for creating the database used in the project. There are 3 steps in this stage:
#
# 1. Download data from the PubMed database with BioPython
# 2. Create the database in PostgreSQL through Python with SQLAlchemy
# 3. Save the downloaded data into the database with Pandas

# %% [markdown]
# ### Step 1: Download the data
#
# In this step I will use the Entrez utilities provided by the BioPython package to download the data from PubMed.

# %%
from Bio import Entrez

### Set up API key and search terms for Entrez:
API_KEY = "81301f2670cac89be2a84fc6ffe183cfad09"
EMAIL = "digicosmos@gmail.com"
SEARCH_TERM = '("epilepsy" [MeSH Major Topic]) AND ("2000/1/1"[ppdat] :"2014/12/31"[ppdat])'
Entrez.email = EMAIL
Entrez.api_key = API_KEY

# %%
# Iteratively run queries to retrieve a list of IDs

handle = Entrez.esearch(db="pubmed", retmax=100, term=SEARCH_TERM)
count = int(Entrez.read(handle)['Count'])

ids = []

for start in range(0, count, 10000):
    handle = Entrez.esearch(db="pubmed", retstart=start, retmax=10000, term=SEARCH_TERM)
    ids += Entrez.read(handle)['IdList']
    handle.close()

assert len(ids) == 35803
assert count == len(ids) # Make sure each article has its own id

# %%
# Prepare four lists to be put into a pandas DataFrame

import datetime

list_id = []
list_title = []
list_date = []
list_authors = []

# %%
# Utility function for retrieving author information

def author_list_as_dicts(authorlist):
    result = []
    for element in authorlist:
        author = {}
        if 'LastName' in element.keys():
            author['LastName'] = element['LastName']
        if 'ForeName' in element.keys():
            author['ForeName'] = element['ForeName']
        if 'Initials' in element.keys():
            author['Initials'] = element['Initials']
        result.append(author)
    return result

#author_list_as_dicts(AuthorsList)

# %%
# Utility function for converting dates saved in a dictionary to string
def date_dict_as_str(d):
    month = int(d['Month'])
    day = int(d['Day'])
    year = int(d['Year'])
    return datetime.date(year, month, day)

# date_dict_as_str(date)

# %%
# Iteratively fetch information on articles, 100 at a time
# Since processing XMLs takes time, this process does not exceed the 10 requests per second limit

for i in range(0, len(ids), 100):
    
    
    if i + 100 < len(ids) - 1:
        j = i+100
    else:
        j = len(ids) - 1
        
    
    handle = Entrez.efetch(db="pubmed", id=ids[i:j], retmode="xml")
    
    print("Retrieved info from PubMed Database, articles {0} to {1}".format(i+1, j))
    
    temp = Entrez.read(handle)
    
    print("Parsing XML document complete.")
    
    # retrieve relevant information from parsed xml, and append them to the lists
    
    for article in temp["PubmedArticle"]:
        id = int(str(article["MedlineCitation"]["PMID"]))
        title = article["MedlineCitation"]["Article"]["ArticleTitle"]
        date = date_dict_as_str(article["PubmedData"]["History"][0])
        authors = None
        if "AuthorList" in article["MedlineCitation"]["Article"].keys():
            authors = author_list_as_dicts(article["MedlineCitation"]["Article"]["AuthorList"])

        list_id.append(id)
        list_title.append(title)
        list_date.append(date)
        if authors is not None:
            list_authors.append(authors)
        else:
            list_authors.append(None)
            
    handle.close()
    temp = None
            
assert len(list_id) == len(ids)
# Out:
# Retrieved info from PubMed Database, articles 1 to 101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 25701 to 25801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 25801 to 25901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 25901 to 26001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26001 to 26101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26101 to 26201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26201 to 26301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26301 to 26401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26401 to 26501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26501 to 26601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26601 to 26701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26701 to 26801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26801 to 26901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 26901 to 27001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27001 to 27101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27101 to 27201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27201 to 27301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27301 to 27401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27401 to 27501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27501 to 27601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27601 to 27701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27701 to 27801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27801 to 27901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 27901 to 28001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28001 to 28101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28101 to 28201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28201 to 28301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28301 to 28401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28401 to 28501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28501 to 28601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28601 to 28701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28701 to 28801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28801 to 28901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 28901 to 29001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29001 to 29101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29101 to 29201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29201 to 29301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29301 to 29401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29401 to 29501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29501 to 29601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29601 to 29701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29701 to 29801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29801 to 29901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 29901 to 30001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30001 to 30101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30101 to 30201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30201 to 30301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30301 to 30401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30401 to 30501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30501 to 30601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30601 to 30701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30701 to 30801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30801 to 30901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 30901 to 31001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31001 to 31101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31101 to 31201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31201 to 31301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31301 to 31401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31401 to 31501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31501 to 31601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31601 to 31701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31701 to 31801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31801 to 31901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 31901 to 32001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32001 to 32101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32101 to 32201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32201 to 32301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32301 to 32401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32401 to 32501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32501 to 32601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32601 to 32701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32701 to 32801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32801 to 32901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 32901 to 33001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33001 to 33101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33101 to 33201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33201 to 33301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33301 to 33401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33401 to 33501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33501 to 33601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33601 to 33701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33701 to 33801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33801 to 33901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 33901 to 34001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34001 to 34101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34101 to 34201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34201 to 34301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34301 to 34401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34401 to 34501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34501 to 34601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34601 to 34701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34701 to 34801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34801 to 34901
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 34901 to 35001
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 35001 to 35101
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 35101 to 35201
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 35201 to 35301
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 35301 to 35401
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 35401 to 35501
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 35501 to 35601
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 35601 to 35701
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 35701 to 35801
# Parsing XML document complete.
# Retrieved info from PubMed Database, articles 35801 to 35803
# Parsing XML document complete.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-e40ce5e85ba9> in <module>()
#      36     temp = None
#      37
# ---> 38 assert len(list_id) == len(ids)
#
# AssertionError:

# %%
len(list_id)
# Out:
# 55802

# %%
import pandas as pd

# %%
# Create a pandas DataFrame from the 4 lists

pubs = pd.DataFrame(PubMedID=list_id, Title=list_title, PubDate=list_date, Authors=list_authors)

# %%
# Create the article DataFrame

articles = pubs[["PubMedID", "Title", "PubDate"]]

# %%
# Create the article author data frame for many-to-many relationships

article_authors = pubs[["PubMedID, Authors"]]

article_authors = article_authors.explode()

# %% [markdown]
# ### Step 2: Use pandas and SQLAlchemy to add downloaded data to database
